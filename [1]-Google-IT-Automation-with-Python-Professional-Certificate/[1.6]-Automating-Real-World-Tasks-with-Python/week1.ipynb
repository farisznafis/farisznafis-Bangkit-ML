# %%
from PIL import Image
im = Image.open("bride.jpg")
im.rotate(45).show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 from PIL import Image
# ----> 2 im = Image.open("bride.jpg")
#       3 im.rotate(45).show()
#
# File c:\Users\faris\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3236, in open(fp, mode, formats)
#    3233     filename = fp
#    3235 if filename:
# -> 3236     fp = builtins.open(filename, "rb")
#    3237     exclusive_fp = True
#    3239 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bride.jpg'

# %%
help(PIL)
# Out:
# Help on package PIL:
#
# NAME
#     PIL - Pillow (Fork of the Python Imaging Library)
#
# DESCRIPTION
#     Pillow is the friendly PIL fork by Jeffrey A. Clark (Alex) and contributors.
#         https://github.com/python-pillow/Pillow/
#
#     Pillow is forked from PIL 1.1.7.
#
#     PIL is the Python Imaging Library by Fredrik Lundh and contributors.
#     Copyright (c) 1999 by Secret Labs AB.
#
#     Use PIL.__version__ for this Pillow version.
#
#     ;-)
#
# PACKAGE CONTENTS
#     BdfFontFile
#     BlpImagePlugin
#     BmpImagePlugin
#     BufrStubImagePlugin
#     ContainerIO
#     CurImagePlugin
#     DcxImagePlugin
#     DdsImagePlugin
#     EpsImagePlugin
#     ExifTags
#     FitsImagePlugin
#     FitsStubImagePlugin
#     FliImagePlugin
#     FontFile
#     FpxImagePlugin
#     FtexImagePlugin
#     GbrImagePlugin
#     GdImageFile
#     GifImagePlugin
#     GimpGradientFile
#     GimpPaletteFile
#     GribStubImagePlugin
#     Hdf5StubImagePlugin
#     IcnsImagePlugin
# ...

# %% [markdown]
# ## [Lab] Scale and convert images using PIL

# %%
# Iterate through each file in the folder For each file:
# Rotate the image 90° clockwise
# Resize the image from 192x192 to 128x128
# Save the image to a new folder in .jpeg format


#!/usr/bin/env python3

from PIL import Image
import os

source_path = "images/"
output_path = "/opt/icons/"

# Ensure the output folder exists
#if not os.path.exists(output_path):
#    os.makedirs(output_path)

#for file in os.listdir(source_path):
#  if file != ".DS_Store":
#    print(str(file))
#    img_path = os.path.join(source_path, file)
#    img = Image.open(img_path)

#    rotated_img = img.rotate(-90)
#    resized_img = rotated_img.resize((128, 128)).convert("RGB")

#    output = os.path.join(output_path, resized_img)
#    resized_img.save(output_path + file, format="jpeg")
#    img.close()

for file in os.listdir(source_path):
    if file.endswith("48dp"):
        im = Image.open(source_path + file)
        im.rotate(270).resize((128,128)).convert("RGB").save(output_path + file, "JPEG")
        im.close()
